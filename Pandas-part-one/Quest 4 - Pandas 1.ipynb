# %% [markdown]
# ## Rishab Vaishya
# ## Class - CSE 8392 Special Topics (Advanced Application Programming)
# ## Quest 3 - Pandas 1
# ## SMU ID – 47505527

# %% [markdown]
# # Example 1 - Option & Settings
#
# https://pandas.pydata.org/pandas-docs/stable/options.html
#
# The API is composed of 5 relevant functions, available directly from the pandas namespace:
#
# 1. get_option() / set_option() - get/set the value of a single option.
# 2. reset_option() - reset one or more options to their default value.
# 3. describe_option() - print the descriptions of one or more options.
# 4. option_context() - execute a codeblock with a set of options that revert to prior settings after execution.

# %% [markdown]
# gets the value of the opion: max_rows to display of a table

# %%
import pandas as pd

pd.get_option("display.max_rows")
# Out:
# 60

# %% [markdown]
# sets the value of the opion: max_rows to display of a table to 101

# %%
pd.set_option("display.max_rows",101)

# displays updated value
pd.get_option("display.max_rows")
# Out:
# 101

# %% [markdown]
# resets the value of the opion: max_rows to display of a table to default

# %%
pd.reset_option("display.max_rows")

# displays updated value
pd.get_option("display.max_rows")
# Out:
# 60

# %% [markdown]
# # Example 2 - Cleaning / Filling Missing Data
#
# https://pandas.pydata.org/pandas-docs/stable/missing_data.html
#
#
# we are gonna use the
# 1. replace() which lets use replace any value with desired value
# 2. fillna() function whic lets you fill all the NaN values with our desired value

# %%
import numpy  as np

# set up a dataframe
df = pd.DataFrame(np.random.randint(-1,10,size=(5, 10)), columns=list('abcdefghij'))
df
# Out:
#    a  b  c  d  e  f  g  h  i  j
# 0  3  5  4  2  3  8  7  6  3  8
# 1  0  4  3  3  1  9  0  5  9  8
# 2  7  5  0  1  3  2  7  4  0  0
# 3  9  3  1 -1  3  2  7  5  1  5
# 4 -1  0  0  7  2  4  4 -1  5  1

# %% [markdown]
# replacing value -1 by NaN, to make some NaN values in table, to fill in later

# %%
df = df.replace(-1, np.nan)
df
# Out:
#      a  b  c    d  e  f  g    h  i  j
# 0  3.0  5  4  2.0  3  8  7  6.0  3  8
# 1  0.0  4  3  3.0  1  9  0  5.0  9  8
# 2  7.0  5  0  1.0  3  2  7  4.0  0  0
# 3  9.0  3  1  NaN  3  2  7  5.0  1  5
# 4  NaN  0  0  7.0  2  4  4  NaN  5  1

# %% [markdown]
# filling Nan values with -1

# %%
df.fillna(-1)
# Out:
#      a  b  c    d  e  f  g    h  i  j
# 0  3.0  5  4  2.0  3  8  7  6.0  3  8
# 1  0.0  4  3  3.0  1  9  0  5.0  9  8
# 2  7.0  5  0  1.0  3  2  7  4.0  0  0
# 3  9.0  3  1 -1.0  3  2  7  5.0  1  5
# 4 -1.0  0  0  7.0  2  4  4 -1.0  5  1

# %% [markdown]
# filling Nan values with 'Missing' string value

# %%
df.fillna('Missing')
# Out:
#          a  b  c        d  e  f  g        h  i  j
# 0        3  5  4        2  3  8  7        6  3  8
# 1        0  4  3        3  1  9  0        5  9  8
# 2        7  5  0        1  3  2  7        4  0  0
# 3        9  3  1  Missing  3  2  7        5  1  5
# 4  Missing  0  0        7  2  4  4  Missing  5  1

# %% [markdown]
# filling Nan values with average/mean value of it's column

# %%
df.fillna(df.mean())
# Out:
#       a  b  c     d  e  f  g    h  i  j
# 0  3.00  5  4  2.00  3  8  7  6.0  3  8
# 1  0.00  4  3  3.00  1  9  0  5.0  9  8
# 2  7.00  5  0  1.00  3  2  7  4.0  0  0
# 3  9.00  3  1  3.25  3  2  7  5.0  1  5
# 4  4.75  0  0  7.00  2  4  4  5.0  5  1

# %% [markdown]
# filling Nan values with max value of it's column

# %%
df.fillna(df.max())
# Out:
#      a  b  c    d  e  f  g    h  i  j
# 0  3.0  5  4  2.0  3  8  7  6.0  3  8
# 1  0.0  4  3  3.0  1  9  0  5.0  9  8
# 2  7.0  5  0  1.0  3  2  7  4.0  0  0
# 3  9.0  3  1  7.0  3  2  7  5.0  1  5
# 4  9.0  0  0  7.0  2  4  4  6.0  5  1

# %% [markdown]
# # Example 3 - Time series / Date functionality
#
# https://pandas.pydata.org/pandas-docs/stable/timeseries.html
#
# The following table shows the type of time-related classes pandas can handle and how to create them.

# %%
df = pd.DataFrame([["Timestamp",'Represents a single timestamp','to_datetime, Timestamp'],
         ["DatetimeIndex",'Index of Timestamp','to_datetime, date_range, bdate_range, DatetimeIndex'],
         ["Period",'Represents a single time span','Period'],
         ["PeriodIndex",'Index of Period','period_range, PeriodIndex']],columns=list(["Class",'Remarks','How to create']))
df
# Out:
#            Class                        Remarks  \
# 0      Timestamp  Represents a single timestamp
# 1  DatetimeIndex             Index of Timestamp
# 2         Period  Represents a single time span
# 3    PeriodIndex                Index of Period
#
#                                        How to create
# 0                             to_datetime, Timestamp
# 1  to_datetime, date_range, bdate_range, Datetime...
# 2                                             Period
# 3                          period_range, PeriodIndex

# %% [markdown]
# Create a range of dates starting from midnight of 9/1/2018 & an interval of 1 hour & 72 values

# %%
timeRange = pd.date_range('9/1/2018', periods=72, freq='H')
# show only first 10
timeRange[:10]
# Out:
# DatetimeIndex(['2018-09-01 00:00:00', '2018-09-01 01:00:00',
#                '2018-09-01 02:00:00', '2018-09-01 03:00:00',
#                '2018-09-01 04:00:00', '2018-09-01 05:00:00',
#                '2018-09-01 06:00:00', '2018-09-01 07:00:00',
#                '2018-09-01 08:00:00', '2018-09-01 09:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %% [markdown]
# Index pandas objects (df) with dates

# %%
df = pd.Series(np.random.randn(len(timeRange)), index=timeRange)
df.head()
# Out:
# 2018-09-01 00:00:00   -1.315265
# 2018-09-01 01:00:00   -0.524184
# 2018-09-01 02:00:00   -0.331979
# 2018-09-01 03:00:00   -0.864254
# 2018-09-01 04:00:00   -1.536040
# Freq: H, dtype: float64

# %% [markdown]
# Change frequency and fill gaps

# %%
# to 45 minute frequency and forward fill
converted = df.asfreq('45Min', method='pad')
converted.head()
# Out:
# 2018-09-01 00:00:00   -1.315265
# 2018-09-01 00:45:00   -1.315265
# 2018-09-01 01:30:00   -0.524184
# 2018-09-01 02:15:00   -0.331979
# 2018-09-01 03:00:00   -0.864254
# Freq: 45T, dtype: float64

# %% [markdown]
# Resample the series to a daily frequency

# %%
df.resample('D').mean()
# Out:
# 2018-09-01    0.065329
# 2018-09-02    0.110969
# 2018-09-03   -0.043462
# Freq: D, dtype: float64

# %% [markdown]
# # Example 4 - Styling
#
# https://pandas.pydata.org/pandas-docs/stable/style.html
#
# Pass your style functions into one of the following methods:
# 1. Styler.applymap: elementwise
# 2. Styler.apply: column-/row-/table-wise

# %%
# set up a dataframe
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan

# %%
# origina style
df.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row0_col0" class="data row0 col0" >1</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row0_col1" class="data row0 col1" >1.32921</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row0_col2" class="data row0 col2" >nan</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row0_col3" class="data row0 col3" >-0.31628</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row0_col4" class="data row0 col4" >-0.99081</td>
#     </tr>    <tr>
#         <th id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row1_col0" class="data row1 col0" >2</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row1_col1" class="data row1 col1" >-1.07082</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row1_col2" class="data row1 col2" >-1.43871</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row1_col3" class="data row1 col3" >0.564417</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row1_col4" class="data row1 col4" >0.295722</td>
#     </tr>    <tr>
#         <th id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row2_col0" class="data row2 col0" >3</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row2_col1" class="data row2 col1" >-1.6264</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row2_col2" class="data row2 col2" >0.219565</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row2_col3" class="data row2 col3" >0.678805</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row2_col4" class="data row2 col4" >1.88927</td>
#     </tr>    <tr>
#         <th id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row3_col0" class="data row3 col0" >4</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row3_col1" class="data row3 col1" >0.961538</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row3_col2" class="data row3 col2" >0.104011</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row3_col3" class="data row3 col3" >-0.481165</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row3_col4" class="data row3 col4" >0.850229</td>
#     </tr>    <tr>
#         <th id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row4_col0" class="data row4 col0" >5</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row4_col1" class="data row4 col1" >1.45342</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row4_col2" class="data row4 col2" >1.05774</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row4_col3" class="data row4 col3" >0.165562</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row4_col4" class="data row4 col4" >0.515018</td>
#     </tr>    <tr>
#         <th id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row5_col0" class="data row5 col0" >6</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row5_col1" class="data row5 col1" >-1.33694</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row5_col2" class="data row5 col2" >0.562861</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row5_col3" class="data row5 col3" >1.39285</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row5_col4" class="data row5 col4" >-0.063328</td>
#     </tr>    <tr>
#         <th id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row6_col0" class="data row6 col0" >7</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row6_col1" class="data row6 col1" >0.121668</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row6_col2" class="data row6 col2" >1.2076</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row6_col3" class="data row6 col3" >-0.00204021</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row6_col4" class="data row6 col4" >1.6278</td>
#     </tr>    <tr>
#         <th id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row7_col0" class="data row7 col0" >8</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row7_col1" class="data row7 col1" >0.354493</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row7_col2" class="data row7 col2" >1.03753</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row7_col3" class="data row7 col3" >-0.385684</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row7_col4" class="data row7 col4" >0.519818</td>
#     </tr>    <tr>
#         <th id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row8_col0" class="data row8 col0" >9</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row8_col1" class="data row8 col1" >1.68658</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row8_col2" class="data row8 col2" >-1.32596</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row8_col3" class="data row8 col3" >1.42898</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row8_col4" class="data row8 col4" >-2.08935</td>
#     </tr>    <tr>
#         <th id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row9_col0" class="data row9 col0" >10</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row9_col1" class="data row9 col1" >-0.12982</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row9_col2" class="data row9 col2" >0.631523</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row9_col3" class="data row9 col3" >-0.586538</td>
#         <td id="T_e5ce1f52_b866_11e8_81a3_fc4596ea5b10row9_col4" class="data row9 col4" >0.29072</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# Let’s write a simple style function that will color negative numbers red and positive numbers black

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# %% [markdown]
# In this case, the cell’s style depends only on it’s own value. That means we should use the Styler.applymap method which works elementwise.

# %%
df.style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
#     #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row0_col0 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row0_col1 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row0_col2 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row0_col3 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row0_col4 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row1_col0 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row1_col1 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row1_col2 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row1_col3 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row1_col4 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row2_col0 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row2_col1 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row2_col2 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row2_col3 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row2_col4 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row3_col0 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row3_col1 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row3_col2 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row3_col3 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row3_col4 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row4_col0 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row4_col1 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row4_col2 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row4_col3 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row4_col4 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row5_col0 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row5_col1 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row5_col2 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row5_col3 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row5_col4 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row6_col0 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row6_col1 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row6_col2 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row6_col3 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row6_col4 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row7_col0 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row7_col1 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row7_col2 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row7_col3 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row7_col4 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row8_col0 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row8_col1 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row8_col2 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row8_col3 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row8_col4 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row9_col0 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row9_col1 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row9_col2 {
#             color:  black;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row9_col3 {
#             color:  red;
#         }    #T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row9_col4 {
#             color:  black;
#         }</style>
# <table id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row0_col0" class="data row0 col0" >1</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row0_col1" class="data row0 col1" >1.32921</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row0_col2" class="data row0 col2" >nan</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row0_col3" class="data row0 col3" >-0.31628</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row0_col4" class="data row0 col4" >-0.99081</td>
#     </tr>    <tr>
#         <th id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row1_col0" class="data row1 col0" >2</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row1_col1" class="data row1 col1" >-1.07082</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row1_col2" class="data row1 col2" >-1.43871</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row1_col3" class="data row1 col3" >0.564417</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row1_col4" class="data row1 col4" >0.295722</td>
#     </tr>    <tr>
#         <th id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row2_col0" class="data row2 col0" >3</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row2_col1" class="data row2 col1" >-1.6264</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row2_col2" class="data row2 col2" >0.219565</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row2_col3" class="data row2 col3" >0.678805</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row2_col4" class="data row2 col4" >1.88927</td>
#     </tr>    <tr>
#         <th id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row3_col0" class="data row3 col0" >4</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row3_col1" class="data row3 col1" >0.961538</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row3_col2" class="data row3 col2" >0.104011</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row3_col3" class="data row3 col3" >-0.481165</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row3_col4" class="data row3 col4" >0.850229</td>
#     </tr>    <tr>
#         <th id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row4_col0" class="data row4 col0" >5</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row4_col1" class="data row4 col1" >1.45342</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row4_col2" class="data row4 col2" >1.05774</td>
#         <td id="T_e5d324e4_b866_11e8_8ad2_fc4596ea5b10row4_col3"

# %% [markdown]
# Now suppose you wanted to highlight the maximum value in each column

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %% [markdown]
# We can’t use .applymap anymore since that operated elementwise. Instead, we’ll turn to .apply which operates columnwise (or rowwise using the axis keyword). Later on we’ll see that something like highlight_max is already defined on Styler so you wouldn’t need to write this yourself.

# %%
df.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_e5d96234_b866_11e8_86b3_fc4596ea5b10row2_col4 {
#             background-color:  yellow;
#         }    #T_e5d96234_b866_11e8_86b3_fc4596ea5b10row6_col2 {
#             background-color:  yellow;
#         }    #T_e5d96234_b866_11e8_86b3_fc4596ea5b10row8_col1 {
#             background-color:  yellow;
#         }    #T_e5d96234_b866_11e8_86b3_fc4596ea5b10row8_col3 {
#             background-color:  yellow;
#         }    #T_e5d96234_b866_11e8_86b3_fc4596ea5b10row9_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row0_col0" class="data row0 col0" >1</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row0_col1" class="data row0 col1" >1.32921</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row0_col2" class="data row0 col2" >nan</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row0_col3" class="data row0 col3" >-0.31628</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row0_col4" class="data row0 col4" >-0.99081</td>
#     </tr>    <tr>
#         <th id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row1_col0" class="data row1 col0" >2</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row1_col1" class="data row1 col1" >-1.07082</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row1_col2" class="data row1 col2" >-1.43871</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row1_col3" class="data row1 col3" >0.564417</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row1_col4" class="data row1 col4" >0.295722</td>
#     </tr>    <tr>
#         <th id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row2_col0" class="data row2 col0" >3</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row2_col1" class="data row2 col1" >-1.6264</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row2_col2" class="data row2 col2" >0.219565</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row2_col3" class="data row2 col3" >0.678805</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row2_col4" class="data row2 col4" >1.88927</td>
#     </tr>    <tr>
#         <th id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row3_col0" class="data row3 col0" >4</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row3_col1" class="data row3 col1" >0.961538</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row3_col2" class="data row3 col2" >0.104011</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row3_col3" class="data row3 col3" >-0.481165</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row3_col4" class="data row3 col4" >0.850229</td>
#     </tr>    <tr>
#         <th id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row4_col0" class="data row4 col0" >5</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row4_col1" class="data row4 col1" >1.45342</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row4_col2" class="data row4 col2" >1.05774</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row4_col3" class="data row4 col3" >0.165562</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row4_col4" class="data row4 col4" >0.515018</td>
#     </tr>    <tr>
#         <th id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row5_col0" class="data row5 col0" >6</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row5_col1" class="data row5 col1" >-1.33694</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row5_col2" class="data row5 col2" >0.562861</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row5_col3" class="data row5 col3" >1.39285</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row5_col4" class="data row5 col4" >-0.063328</td>
#     </tr>    <tr>
#         <th id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row6_col0" class="data row6 col0" >7</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row6_col1" class="data row6 col1" >0.121668</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row6_col2" class="data row6 col2" >1.2076</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row6_col3" class="data row6 col3" >-0.00204021</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row6_col4" class="data row6 col4" >1.6278</td>
#     </tr>    <tr>
#         <th id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row7_col0" class="data row7 col0" >8</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row7_col1" class="data row7 col1" >0.354493</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row7_col2" class="data row7 col2" >1.03753</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row7_col3" class="data row7 col3" >-0.385684</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row7_col4" class="data row7 col4" >0.519818</td>
#     </tr>    <tr>
#         <th id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row8_col0" class="data row8 col0" >9</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row8_col1" class="data row8 col1" >1.68658</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row8_col2" class="data row8 col2" >-1.32596</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row8_col3" class="data row8 col3" >1.42898</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row8_col4" class="data row8 col4" >-2.08935</td>
#     </tr>    <tr>
#         <th id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row9_col0" class="data row9 col0" >10</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row9_col1" class="data row9 col1" >-0.12982</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row9_col2" class="data row9 col2" >0.631523</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row9_col3" class="data row9 col3" >-0.586538</td>
#         <td id="T_e5d96234_b866_11e8_86b3_fc4596ea5b10row9_col4" class="data row9 col4" >0.29072</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# It's encourage you to use method chains to build up a style piecewise, before finally rending at the end of the chain.

# %%
df.style.\
    applymap(color_negative_red).\
    apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row0_col0 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row0_col1 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row0_col2 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row0_col3 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row0_col4 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row1_col0 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row1_col1 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row1_col2 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row1_col3 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row1_col4 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row2_col0 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row2_col1 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row2_col2 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row2_col3 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row2_col4 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row3_col0 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row3_col1 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row3_col2 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row3_col3 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row3_col4 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row4_col0 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row4_col1 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row4_col2 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row4_col3 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row4_col4 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row5_col0 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row5_col1 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row5_col2 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row5_col3 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row5_col4 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row6_col0 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row6_col1 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row6_col2 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row6_col3 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row6_col4 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row7_col0 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row7_col1 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row7_col2 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row7_col3 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row7_col4 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row8_col0 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row8_col1 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row8_col2 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row8_col3 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row8_col4 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row9_col0 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row9_col1 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row9_col2 {
#             color:  black;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row9_col3 {
#             color:  red;
#             : ;
#         }    #T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row9_col4 {
#             color:  black;
#             : ;
#         }</style>
# <table id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row0_col0" class="data row0 col0" >1</td>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row0_col1" class="data row0 col1" >1.32921</td>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row0_col2" class="data row0 col2" >nan</td>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row0_col3" class="data row0 col3" >-0.31628</td>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row0_col4" class="data row0 col4" >-0.99081</td>
#     </tr>    <tr>
#         <th id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row1_col0" class="data row1 col0" >2</td>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row1_col1" class="data row1 col1" >-1.07082</td>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row1_col2" class="data row1 col2" >-1.43871</td>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row1_col3" class="data row1 col3" >0.564417</td>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row1_col4" class="data row1 col4" >0.295722</td>
#     </tr>    <tr>
#         <th id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row2_col0" class="data row2 col0" >3</td>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row2_col1" class="data row2 col1" >-1.6264</td>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row2_col2" class="data row2 col2" >0.219565</td>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row2_col3" class="data row2 col3" >0.678805</td>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row2_col4" class="data row2 col4" >1.88927</td>
#     </tr>    <tr>
#         <th id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_e5deb5ba_b866_11e8_9922_fc4596ea5b10row3_col0" class="data row3 col0" >4</t

# %% [markdown]
# # Example 5 - Comparing with SQL
#
# https://pandas.pydata.org/pandas-docs/stable/comparison_with_sql.html
#
# Importing up a dummy table from github for us to use as an example

# %%
url = 'https://raw.github.com/pandas-dev/pandas/master/pandas/tests/data/tips.csv'
tips = pd.read_csv(url)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 5.1 select with Where
#
# how it's done in SQL :
# >SELECT * <br>
# >FROM tips<br>
# >WHERE time = 'Dinner'<br>
# >LIMIT 5;<br>
#
# the panda equivalent for it

# %%
tips[tips['time'] == 'Dinner'].head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 5.2 'Update' clause
#
# how it's done in SQL :
# >UPDATE tips<br>
# >SET tip = tip*2<br>
# >WHERE tip < 2;<br>
#
# the panda equivalent for multiplyin the tip by 2 for all tips less than 2

# %%
tips.loc[tips['tip'] < 2, 'tip'] *= 2
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  2.02  Female     No  Sun  Dinner     2
# 1       10.34  3.32    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 5.3 'Delete' clause
#
# how it's done in SQL :
# >DELETE FROM tips<br>
# >WHERE tip ==2.02;<br>
#
# In pandas we select the rows that should remain, instead of deleting them

# %%
tips = tips.loc[tips['tip'] != 2.02]
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       10.34  3.32    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4

# %% [markdown]
# ## 5.4 Full Join
# show all records from both tables
# >SELECT *<br>
# >FROM df1<br>
# >FULL OUTER JOIN df2<br>
# >  ON df1.key = df2.key;<br>
#
# we are are creating 2 tables df1 & df2 onto which we'll perform full outer join

# %%
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'],'value': np.random.randn(4)}) 
df1.head()
# Out:
#   key     value
# 0   A  1.264103
# 1   B  0.290035
# 2   C -1.970288
# 3   D  0.803906

# %%
df2 = pd.DataFrame({'key': ['B', 'D', 'D', 'E'],'value': np.random.randn(4)})
df2.head()
# Out:
#   key     value
# 0   B  1.030550
# 1   D  0.118098
# 2   D -0.021853
# 3   E  0.046841

# %%
pd.merge(df1, df2, on='key', how='outer')
# Out:
#   key   value_x   value_y
# 0   A  1.264103       NaN
# 1   B  0.290035  1.030550
# 2   C -1.970288       NaN
# 3   D  0.803906  0.118098
# 4   D  0.803906 -0.021853
# 5   E       NaN  0.046841
